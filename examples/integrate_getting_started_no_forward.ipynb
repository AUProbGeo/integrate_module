# %% [markdown]
# # Getting started with INTEGRATE - with no forward code
#
# This notebook contains a simple example of getting started with INTEGRATE - with no forward code
#
# 0. Load prior data (prior models and prior data) (DAUGAARD.h5)
# 1. Perform probabilistic inversion using integrate_rejection.
# 2. Plot some results
#
# GA-AEM is not need to run this example.

# %%
try:
    # Check if the code is running in an IPython kernel (which includes Jupyter notebooks)
    get_ipython()
    # If the above line doesn't raise an error, it means we are in a Jupyter environment
    # Execute the magic commands using IPython's run_line_magic function
    get_ipython().run_line_magic('load_ext', 'autoreload')
    get_ipython().run_line_magic('autoreload', '2')
except:
    # If get_ipython() raises an error, we are not in a Jupyter environment
    # # # # #%load_ext autoreload
    # # # # #%autoreload 2
    pass

# %%
import integrate as ig
# check if parallel computations can be performed
parallel = ig.use_parallel(showInfo=1)
hardcopy = True 
import matplotlib.pyplot as plt
# Out:
# Notebook detected. Parallel processing is OK.

# %% [markdown]
# ## 0. Get some TTEM data
# A number of test cases are available in the INTEGRATE package
# To see which cases are available, check the `get_case_data` function
#
# The code below will download the file DAUGAARD_AVG.h5 that contains
# a number of TTEM soundings from DAUGAARD, Denmark.
# It will also download the corresponding GEX file, TX07_20231016_2x4_RC20-33.gex,
# that contains information about the TTEM system used.

# %%
case = 'DAUGAARD'
files = ig.get_case_data(case=case,  loadType='prior_data')
f_data_h5 = files[0]
f_prior_h5 = files[-1]
file_gex= ig.get_gex_file_from_data(f_data_h5)

print("Using data file: %s" % f_data_h5)
print("Using GEX file: %s" % file_gex)
print("Using prior model and data file: %s" % f_prior_h5)
# Out:
# Getting data for case: DAUGAARD
# --> Got data for case: DAUGAARD
# Using data file: DAUGAARD_AVG.h5
# Using GEX file: TX07_20231016_2x4_RC20-33.gex
# Using prior model and data file: daugaard_standard_new_N1000000_dmax90_TX07_20231016_2x4_RC20-33_Nh280_Nf12.h5

# %% [markdown]
# ### Plot the geometry and the data
# ig.plot_geometry plots the geometry of the data, i.e. the locations of the soundings.
# ig.plot_data plots the data, i.e. the measured data for each sounding.

# %%
# The next line plots LINE, ELEVATION and data id, as three scatter plots
# ig.plot_geometry(f_data_h5)
# Each of these plots can be plotted separately by specifying the pl argument
ig.plot_geometry(f_data_h5, pl='LINE')
ig.plot_geometry(f_data_h5, pl='ELEVATION')
ig.plot_geometry(f_data_h5, pl='id')
# Out:
# f_data_h5=DAUGAARD_AVG.h5
# f_data_h5=DAUGAARD_AVG.h5
# f_data_h5=DAUGAARD_AVG.h5

# %%
# The data, d_obs and d_std, can be plotted using ig.plot_data
ig.plot_data(f_data_h5, hardcopy=hardcopy)

# %% [markdown]
# ## 1. Setup the prior model ($\rho(\mathbf{m},\mathbf{d}))
#
# In this case prior data and models are allready available in the HDF% in 'f_prior_h5'.

# %%
# Plot some summary statistics of the prior model, to QC the prior choice
ig.plot_prior_stats(f_prior_h5, hardcopy=hardcopy)

# %% [markdown]
# It can be useful to compare the prior data to the observed data before inversion. If there is little to no overlap of the observed data with the prior data, there is little chance that the inversion will go well. This would be an indication of inconsistency.
# In the figure below, one can see that the observed data (red) is clearly within the space of the prior data.

# %%
ig.plot_data_prior(f_prior_h5,f_data_h5,nr=1000,hardcopy=hardcopy)
# Out:
# True

# %% [markdown]
# ## 2. Sample the posterior $\sigma(\mathbf{m})$
#
# The posterior distribution is sampled using the extended rejection sampler.

# %%
# Rejection sampling of the posterior can be done using
#f_post_h5 = ig.integrate_rejection(f_prior_h5, f_data_h5)

# One can also control a number of options.
# One can choose to make use of only a subset of the prior data. Decreasing the sample size used makes the inversion faster, but increasingly approximate
N_use = 2000000 # Max lookup table size
N_use = 100000
T_base = 1 # The base annealing temperature. 
autoT = 1  # Automatically set the annealing temperature
f_post_h5 = ig.integrate_rejection(f_prior_h5, 
                                   f_data_h5, 
                                   f_post_h5 = 'POST.h5', 
                                   N_use = N_use, 
                                   autoT = autoT,
                                   T_base = T_base,                            
                                   showInfo=1, 
                                   parallel=parallel)
# Out:
# File POST.h5 allready exists
# Overwriting...
# Loading data from DAUGAARD_AVG.h5. Using data types: [1]
#   - D1: id_prior=1,    gaussian, Using 11693/40 data
# Loading prior data from daugaard_standard_new_N1000000_dmax90_TX07_20231016_2x4_RC20-33_Nh280_Nf12.h5. Using prior data ids: [1]
#   - /D1:  N,nd = 100000/40
# <--INTEGRATE_REJECTION-->
# f_prior_h5=daugaard_standard_new_N1000000_dmax90_TX07_20231016_2x4_RC20-33_Nh280_Nf12.h5, f_data_h5=DAUGAARD_AVG.h5
# f_post_h5=POST.h5
# Rejection Sampling:   0%|                                                                                                                   | 0/1462 [00:00<?, ?it/s]
# Rejection Sampling:   0%|                                                                                                                   | 0/1462 [00:00<?, ?it/s]
# Rejection Sampling:   0%|                                                                                                                   | 0/1462 [00:00<?, ?it/s]
# Rejection Sampling:   0%|                                                                                                                   | 0/1462 [00:00<?, ?it/s]
# Rejection Sampling:   0%|                                                                                                                   | 0/1462 [00:00<?, ?it/s]
# Rejection Sampling:   0%|                                                                                                                   | 0/1461 [00:00<?, ?it/s]
# Rejection Sampling:   0%|                                                                                                                   | 0/1461 [00:00<?, ?it/s]
# Rejection Sampling:   0%|                                                                                                                   | 0/1461 [00:00<?, ?it/s]
# Rejection Sampling:   0%|▏                                                                                                          | 2/1462 [00:00<01:23, 17.42it/s]
# Rejection Sampling:   0%|▏                                                                                                          | 3/1462 [00:00<01:10, 20.56it/s]
# Rejection Sampling:   0%|▏                                                                                                          | 2/1462 [00:00<01:22, 17.60it/s]
# Rejection Sampling:   0%|▏                                                                                                          | 3/1462 [00:00<01:12, 20.17it/s]
# Rejection Sampling:   0%|▏                                                                                                          | 2/1462 [00:00<01:22, 17.69it/s]
# Rejection Sampling:   0%|▏                                                                                                          | 2/1461 [00:00<01:31, 15.90it/s]
# Rejection Sampling:   0%|▏                                                                                                          | 2/1461 [00:00<01:26, 16.89it/s]
# Rejection Sampling:   0%|                                                                                                           | 1/1461 [00:00<02:35,  9.40it/s]
# Rejection Sampling:   0%|▎                                                                                                          | 4/1462 [00:00<01:29, 16.38it/s]
# Rejection Sampling:   0%|▎                                                                                                          | 4/1462 [00:00<01:26, 16.76it/s]
# Rejection Sampling:   0%|▎                                                                                                          | 4/1462 [00:00<01:42, 14.21it/s]
# Rejection Sampling:   0%|▍                                                                                                          | 6/1462 [00:00<01:22, 17.62it/s]
# Rejection Sampling:   0%|▎                                                                                                          | 4/1461 [00:00<01:34, 15.36it/s]
# Rejection Sampling:   0%|▎                                                                                                          | 4/1461 [00:00<01:29, 16.37it/s]
# Rejection Sampling:   0%|▍                                                                                                          | 6/1462 [00:00<01:21, 17.94it/s]
# Rejection Sampling:   0%|▏                                                                                                          | 3/1461 [00:00<01:49, 13.35it/s]
# Rejection Sampling:   0%|▍                                                                                                          | 6/1462 [00:00<01:29, 16.32it/s]
# Rejection Sampling:   0%|▍                                                                                                          | 6/1462 [00:00<01:28, 16.47it/s]
# Rejection Sampling:   0%|▍                                                                                                          | 6/1462 [00:00<01:34, 15.41it/s]
# Rejection Sampling:   1%|▌                                                                                                          | 8/1462 [00:00<01:26, 16.85it/s]
# Rejection Sampling:   0%|▍                                                                                                          | 6/1461 [00:00<01:33, 15.50it/s]
# Rejection Sampling:   1%|▌                                                                                                          | 8/1462 [00:00<01:23, 17.34it/s]
# Rejection Sampling:   0%|▍                                                                                                          | 6/1461 [00:00<01:29, 16.18it/s]
# Rejection Sampling:   0%|▎                                                                                                          | 5/1461 [00:00<01:35, 15.32it/s]
# Rejection Sampling:   1%|▌                                                                                                          | 8/1462 [00:00<01:31, 15.83it/s]
# Rejection Sampling:   1%|▌                                                                                                          | 8/1462 [00:00<01:29, 16.17it/s]
# Rejection Sampling:   1%|▌                                                                                                          | 8/1462 [00:00<01:33, 15.56it/s]
# Rejection Sampling:   1%|▋                                                                                                         | 10/1462 [00:00<01:27, 16.57it/s]
# Rejection Sampling:   1%|▌                                                                                                          | 8/1461 [00:00<01:34, 15.38it/s]
# Rejection Sampling:   1%|▋                                                                                                         | 10/1462 [00:00<01:29, 16.23it/s]
# Rejection Sampling:   0%|▌                                                                                                          | 7/1461 [00:00<01:31, 15.87it/s]
# Rejection Sampling:   1%|▌                                                                                                          | 8/1461 [00:00<01:33, 15.55it/s]
# Rejection Sampling:   1%|▋                                                                                                         | 10/1462 [00:00<01:29, 16.19it/s]
# Rejection Sampling:   1%|▋                                                                                                         | 10/1462 [00:00<01:31, 15.82it/s]
# Rejection Sampling:   1%|▋                                                                                                         | 10/1462 [00:00<01:32, 15.75it/s]
# Rejection Sampling:   1%|▋                                                                                                         | 10/1461 [00:00<01:34, 15.36it/s]
# Rejection Sampling:   1%|▋                                                                                                          | 9/1461 [00:00<01:31, 15.80it/s]
# Rejection Sampling:   1%|▊                                                                                                         | 12/1462 [00:00<01:31, 15.89it/s]
# Rejection Sampling:   1%|▊                                                                                                         | 12/1462 [00:00<01:30, 16.09it/s]
# Rejection Sampling:   1%|▋                                                                                                         | 10/1461 [00:00<01:32, 15.62it/s]
# Rejection Sampling:   1%|▊                                                                                                         | 12/1462 [00:00<01:30, 16.01it/s]
# Rejection Sampling:   1%|▊                                                                                                         | 12/1462 [00:00<01:31, 15.85it/s]
# Rejection Sampling:   1%|▊                                                                                                         | 12/1462 [00:00<01:34, 15.39it/s]
# Rejection Sampling:   1%|▊                                                                                                         | 12/1461 [00:00<01:32, 15.61it/s]
# Rejection Sampling:   1%|▊                                                                                                         | 11/1461 [00:00<01:31, 15.89it/s]
# Rejection Sampling:   1%|█                                                                                                         | 14/1462 [00:00<01:30, 15.92it/s]
# Rejection Sampling:   1%|█                                                                                                         | 14/1462 [00:00<01:31, 15.76it/s]
# Rejection Sampling:   1%|▊                                                                                                         | 12/1461 [00:00<01:33, 15.43it/s]
# Rejection Sampling:   1%|█                                                                                                         | 14/1462 [00:00<01:31, 15.83it/s]
# Rejection Sampling:   1%|█                                                                                                         | 14/1462 [00:00<01:31, 15.80it/s]
# Rejection Sampling:   1%|█                                                                                                         | 14/1462 [00:00<01:31, 15.87it/s]
# Rejection Sampling:   1%|█                                                                                                         | 14/1461 [00:00<01:31, 15.73it/s]
# Rejection Sampling:   1%|█                                                                                                         | 14/1461 [00:00<01:30, 15.98it/s]
# Rejection Sampling:   1%|█▏                                                                                                        | 16/1462 [00:00<01:30, 15.93it/s]
# Rejection Sampling:   1%|▉                                                                                                         | 13/1461 [00:00<01:31, 15.82it/s]
# Rejection Sampling:   1%|█▏                                                                                                        | 16/1462 [00:00<01:35, 15.10it/s]
# Rejection Sampling:   1%|█▏                                                                                                        | 16/1462 [00:01<01:31, 15.83it/s]
# Rejection Sampling:   1%|█▏                                                                                                        | 16/1462 [00:01<01:31, 15.80it/s]
# Rejection Sampling:   1%|█▏                                                                                                        | 16/1462 [00:00<01:29, 16.07it/s]
# Rejection Sampling:   1%|█▏                                                                                                        | 16/1461 [00:01<01:32, 15.69it/s]
# Rejection Sampling:   1%|█▏                                                                                                        | 16/1461 [00:01<01:31, 15.86it/s]
# Rejection Sampling:   1%|█▎                                                                                                        | 18/1462 [00:01<01:30, 15.92it/s]
# Rejection Sampling:   1%|█                                                                                                         | 15/1461 [00:00<01:31, 15.78it/s]
# Rejection Sampling:   1%|█▎                                                                                                        | 18/1462 [00:01<01:34, 15.34it/s]
# Rejection Sampling:   1%|█▎                                                                                                        | 18/1462 [00:01<01:31, 15.84it/s]
# Rejection Sampling:   1%|█▎                                                                                                        | 18/1462 [00:01<01:31, 15.78it/s]
# Rejection Sampling:   1%|█▎                                                                                                        | 18/1462 [00:01<01:30, 16.01it/s]
# Rejection Sampling:   1%|█▎                                                                                                        | 18/1461 [00:01<01:31, 15.77it/s]
# Rejection Sampling:   1%|█▍                                                                                                        | 20/1462 [00:01<01:30, 15.92it/s]
# Rejection Sampling:   1%|█▎                                                                                                        | 18/1461 [00:01<01:30, 15.94it/s]
# Rejection Sampling:   1%|█▏                                                                                                        | 17/1461 [00:01<01:33, 15.40it/s]
# Rejection Sampling:   1%|█▍                                                                                                        | 20/1462 [00:01<01:30, 16.00it/s]
# Rejection Sampling:   1%|█▍                                                                                                        | 20/1462 [00:01<01:31, 15.77it/s]
# Rejection Sampling:   1%|█▍                                                                                                        | 20/1462 [00:01<01:30, 15.87it/s]
# Rejection Sampling:   1%|█▍                                                                                                        | 20/1462 [00:01<01:31, 15.72it/s]
# Rejection Sampling:   1%|█▍                                                                                                        | 19/1461 [00:01<01:30, 15.90it/s]
# Rejection Sampling:   1%|█▍                                                                                                        | 20/1461 [00:01<01:32, 15.63it/s]
# Rejection Sampling:   1%|█▍                                                                                                        | 20/1461 [00:01<01:31, 15.73it/s]
# Rejection Sampling:   2%|█▌                                                                                                        | 22/1462 [00:01<01:31, 15.67it/s]
# Rejection Sampling:   2%|█▌                                                                                                        | 22/1462 [00:01<01:28, 16.25it/s]
# Rejection Sampling:   2%|█▌                                                                                                        | 22/1462 [00:01<01:32, 15.62it/s]
# Rejection Sampling:   2%|█▌                                                                                                        | 22/1462 [00:01<01:31, 15.73it/s]
# Rejection Sampling:   2%|█▌                                                                                                        | 22/1462 [00:01<01:32, 15.64it/s]
# Rejection Sampling:   2%|█▌                                                                                                        | 22/1461 [00:01<01:32, 15.59it/s]
# Rejection Sampling:   2%|█▌                                                                                                        | 22/1461 [00:01<01:31, 15.66it/s]
# Rejection Sampling:   2%|█▋                                                                                                        | 24/1462 [00:01<01:29, 16.02it/s]
# Rejection Sampling:   2%|█▋                                                                                                        | 24/1462 [00:01<01:32, 15.60it/s]
# Rejection Sampling:   1%|█▌                                                                                                        | 21/1461 [00:01<01:32, 15.56it/s]
# Rejection Sampling:   2%|█▋                                                                                                        | 24/1462 [00:01<01:32, 15.59it/s]
# Rejection Sampling:   2%|█▋                                                                                                        | 24/1462 [00:01<01:32, 15.61it/s]
# Rejection Sampling:   2%|█▋                                                                                                        | 24/1462 [00:01<01:32, 15.51it/s]
# Rejection Sampling:   2%|█▋                                                                                                        | 24/1461 [00:01<01:32, 15.60it/s]
# Rejection Sampling:   2%|█▋                                                                                                        | 24/1461 [00:01<01:32, 15.52it/s]
# Rejection Sampling:   2%|█▉                                                                                                        | 26/1462 [00:01<01:30, 15.83it/s]
# Rejection Sampling:   2%|█▉                                                                                                        | 26/1462 [00:01<01:32, 15.55it/s]
# Rejection Sampling:   2%|█▋                                                                                                        | 23/1461 [00:01<01:32, 15.62it/s]
# Rejection Sampling:   2%|█▉                                                                                                        | 26/1462 [00:01<01:32, 15.58it/s]
# Rejection Sampling:   2%|█▉                                                                                                        | 26/1462 [00:01<01:32, 15.58it/s]
# Rejection Sampling:   2%|█▉                                                                                                        | 26/1462 [00:01<01:32, 15.48it/s]
# Rejection Sampling:   2%|█▊                                                                                                        | 25/1461 [00:01<01:31, 15.67it/s]
# Rejection Sampling:   2%|█▉                                                                                                        | 26/1461 [00:01<01:32, 15.51it/s]
# Rejection Sampling:   2%|█▉                                                                                                        | 26/1461 [00:01<01:32, 15.53it/s]
# Rejection Sampling:   3%|███▋                                                                                                      | 50/1461 [00:03<01:30, 15.68it/s]
# Rejection Sampling:   3%|███▋                                                                                                      | 50/1461 [00:03<01:30, 15.64it/s]
# Rejection Sampling:   3%|███▌                                                                                                      | 49/1461 [00:03<01:30, 15.66it/s]
# Rejection Sampling:   4%|███▊                                                                                                      | 52/1462 [00:03<01:30, 15.66it/s]
# Rejection Sampling:   4%|███▊                                                                                                      | 52/1462 [00:03<01:30, 15.64it/s]
# Rejection Sampling:   4%|███▊                                                                                                      | 52/1462 [00:03<01:30, 15.56it/s]
# Rejection Sampling:   4%|███▊                                                                                                      | 52/1462 [00:03<01:31, 15.47it/s]
# Rejection Sampling:   4%|███▊                                                                                                      | 52/1462 [00:03<01:30, 15.66it/s]
# Rejection Sampling:   4%|███▊                                                                                                      | 52/1461 [00:03<01:30, 15.54it/s]
# Rejection Sampling:   3%|███▋                                                                                                      | 51/1461 [00:03<01:30, 15.55it/s]
# Rejection Sampling:   4%|███▊                                                                                                      | 52/1461 [00:03<01:30, 15.52it/s]
# Rejection Sampling:   4%|███▉                                                                                                      | 54/1462 [00:03<01:30, 15.54it/s]
# Rejection Sampling:   4%|███▉                                                                                                      | 54/1462 [00:03<01:30, 15.55it/s]
# Rejection Sampling:   4%|███▉                                                                                                      | 54/1462 [00:03<01:30, 15.57it/s]
# Rejection Sampling:   4%|███▉                                                                                                      | 54/1462 [00:03<01:29, 15.75it/s]
# Rejection Sampling:   4%|███▉                                                                                                      | 54/1462 [00:03<01:30, 15.53it/s]
# Rejection Sampling:   4%|███▊                                                                                                      | 53/1461 [00:03<01:30, 15.58it/s]
# Rejection Sampling:   4%|███▉                                                                                                      | 54/1461 [00:03<01:30, 15.53it/s]
# Rejection Sampling:   4%|███▉                                                                                                      | 54/1461 [00:03<01:30, 15.47it/s]
# Rejection Sampling:   4%|████                                                                                                      | 56/1462 [00:03<01:30, 15.53it/s]
# Rejection Sampling:   4%|████                                                                                                      | 56/1462 [00:03<01:31, 15.44it/s]
# Rejection Sampling:   4%|████                                                                                                      | 56/1462 [00:03<01:30, 15.53it/s]
# Rejection Sampling:   4%|████                                                                                                      | 56/1462 [00:03<01:30, 15.62it/s]
# Rejection Sampling:   4%|████                                                                                                      | 56/1462 [00:03<01:30, 15.52it/s]
# Rejection Sampling:   4%|████                                                                                                      | 56/1461 [00:03<01:30, 15.53it/s]
# Rejection Sampling:   4%|████                                                                                                      | 56/1461 [00:03<01:30, 15.51it/s]
# Rejection Sampling:   4%|████▏                                                                                                     | 58/1462 [00:03<01:30, 15.57it/s]
# Rejection Sampling:   4%|███▉                                                                                                      | 55/1461 [00:03<01:30, 15.47it/s]
# Rejection Sampling:   4%|████▏                                                                                                     | 58/1462 [00:03<01:30, 15.50it/s]
# Rejection Sampling:   4%|████▏                                                                                                     | 58/1462 [00:03<01:30, 15.50it/s]
# Rejection Sampling:   4%|████▏                                                                                                     | 58/1462 [00:03<01:30, 15.52it/s]
# Rejection Sampling:   4%|████▏                                                                                                     | 58/1462 [00:03<01:30, 15.58it/s]
# Rejection Sampling:   4%|████▏                                                                                                     | 58/1461 [00:03<01:29, 15.59it/s]
# Rejection Sampling:   4%|████▏                                                                                                     | 57/1461 [00:03<01:30, 15.58it/s]
# Rejection Sampling:   4%|████▏                                                                                                     | 58/1461 [00:03<01:30, 15.52it/s]
# Rejection Sampling:   4%|████▎                                                                                                     | 60/1462 [00:03<01:30, 15.57it/s]
# Rejection Sampling:   4%|████▎                                                                                                     | 60/1462 [00:03<01:33, 14.96it/s]
# Rejection Sampling:   4%|████▎                                                                                                     | 60/1462 [00:03<01:29, 15.70it/s]
# Rejection Sampling:   4%|████▎                                                                                                     | 60/1462 [00:03<01:30, 15.56it/s]
# Rejection Sampling:   4%|████▎                                                                                                     | 60/1462 [00:03<01:30, 15.54it/s]
# Rejection Sampling:   4%|████▍                                                                                                     | 62/1462 [00:03<01:29, 15.61it/s]
# Rejection Sampling:   4%|████▎                                                                                                     | 60/1461 [00:03<01:30, 15.54it/s]
# Rejection Sampling:   4%|████▎                                                                                                     | 59/1461 [00:03<01:30, 15.55it/s]
# Rejection Sampling:   4%|████▎                                                                                                     | 60/1461 [00:03<01:29, 15.58it/s]
# Rejection Sampling:   4%|████▍                                                                                                     | 62/1462 [00:03<01:29, 15.71it/s]
# Rejection Sampling:   4%|████▍                                                                                                     | 62/1462 [00:03<01:30, 15.55it/s]
# Rejection Sampling:   4%|████▍                                                                                                     | 62/1462 [00:03<01:30, 15.54it/s]
# Rejection Sampling:   4%|████▍                                                                                                     | 62/1462 [00:03<01:30, 15.47it/s]
# Rejection Sampling:   4%|████▍                                                                                                     | 62/1461 [00:03<01:29, 15.63it/s]
# Rejection Sampling:   4%|████▍                                                                                                     | 61/1461 [00:03<01:29, 15.59it/s]
# Rejection Sampling:   4%|████▍                                                                                                     | 62/1461 [00:03<01:29, 15.56it/s]
# Rejection Sampling:   4%|████▋                                                                                                     | 64/1462 [00:04<01:28, 15.79it/s]
# Rejection Sampling:   4%|████▋                                                                                                     | 64/1462 [00:04<01:29, 15.58it/s]
# Rejection Sampling:   4%|████▋                                                                                                     | 64/1462 [00:04<01:28, 15.79it/s]
# Rejection Sampling:   4%|████▋                                                                                                     | 64/1462 [00:04<01:31, 15.30it/s]
# Rejection Sampling:   4%|████▋                                                                                                     | 64/1462 [00:04<01:31, 15.22it/s]
# Rejection Sampling:   4%|████▋                                                                                                     | 64/1461 [00:04<01:28, 15.71it/s]
# Rejection Sampling:   5%|████▊                                                                                                     | 66/1462 [00:04<01:28, 15.74it/s]
# Rejection Sampling:   4%|████▋                                                                                                     | 64/1461 [00:04<01:29, 15.60it/s]
# Rejection Sampling:   5%|████▊                                                                                                     | 66/1462 [00:04<01:29, 15.57it/s]
# Rejection Sampling:   4%|████▌                                                                                                     | 63/1461 [00:04<01:29, 15.55it/s]
# Rejection Sampling:   5%|████▊                                                                                                     | 66/1462 [00:04<01:28, 15.70it/s]
# Rejection Sampling:   5%|████▊                                                                                                     | 66/1462 [00:04<01:28, 15.74it/s]
# Rejection Sampling:   5%|████▊                                                                                                     | 66/1462 [00:04<01:29, 15.62it/s]
# Rejection Sampling:   5%|████▊                                                                                                     | 66/1461 [00:04<01:29, 15.53it/s]
# Rejection Sampling:   5%|████▊                                                                                                     | 66/1461 [00:04<01:29, 15.54it/s]
# Rejection Sampling:   5%|████▉                                                                                                     | 68/1462 [00:04<01:29, 15.57it/s]
# Rejection Sampling:   4%|████▋                                                                                                     | 65/1461 [00:04<01:29, 15.56it/s]
# Rejection Sampling:   5%|████▉                                                                                                     | 68/1462 [00:04<01:29, 15.60it/s]
# Rejection Sampling:   5%|████▉                                                                                                     | 68/1462 [00:04<01:28, 15.73it/s]
# Rejection Sampling:   5%|████▉                                                                                                     | 68/1462 [00:04<01:28, 15.67it/s]
# Rejection Sampling:   5%|████▉                                                                                                     | 68/1462 [00:04<01:29, 15.62it/s]
# Rejection Sampling:   5%|████▉                                                                                                     | 68/1461 [00:04<01:28, 15.69it/s]
# Rejection Sampling:   5%|████▊                                                                                                     | 67/1461 [00:04<01:28, 15.68it/s]
# Rejection Sampling:   5%|█████                                                                                                     | 70/1462 [00:04<01:28, 15.73it/s]
# Rejection Sampling:   5%|████▉                                                                                                     | 68/1461 [00:04<01:29, 15.58it/s]
# Rejection Sampling:   5%|█████                                                                                                     | 70/1462 [00:04<01:34, 14.79it/s]
# Rejection Sampling:   5%|█████                                                                                                     | 70/1462 [00:04<01:28, 15.76it/s]
# Rejection Sampling:   5%|█████                                                                                                     | 70/1462 [00:04<01:28, 15.71it/s]
# Rejection Sampling:   5%|█████                                                                                                     | 70/1462 [00:04<01:28, 15.75it/s]
# Rejection Sampling:   5%|█████▏                                                                                                    | 72/1462 [00:04<01:28, 15.79it/s]
# Rejection Sampling:   5%|█████                                                                                                     | 70/1461 [00:04<01:28, 15.70it/s]
# Rejection Sampling:   5%|█████                                                                                                     | 69/1461 [00:04<01:28, 15.71it/s]
# ...
# Rejection Sampling:  99%|███████████████████████████████████████████████████████████████████████████████████████████████████████ | 1448/1462 [01:32<00:00, 15.61it/s]
# Rejection Sampling:  98%|██████████████████████████████████████████████████████████████████████████████████████████████████████▏ | 1436/1462 [01:32<00:01, 15.60it/s]
# Rejection Sampling:  99%|██████████████████████████████████████████████████████████████████████████████████████████████████████▋ | 1444/1462 [01:32<00:01, 15.60it/s]
# Rejection Sampling:  99%|██████████████████████████████████████████████████████████████████████████████████████████████████████▌ | 1441/1461 [01:32<00:01, 15.49it/s]
# Rejection Sampling:  99%|███████████████████████████████████████████████████████████████████████████████████████████████████████▎| 1452/1462 [01:32<00:00, 15.63it/s]
# Rejection Sampling:  99%|██████████████████████████████████████████████████████████████████████████████████████████████████████▌ | 1442/1462 [01:32<00:01, 15.62it/s]
# Rejection Sampling:  99%|███████████████████████████████████████████████████████████████████████████████████████████████████████ | 1448/1461 [01:32<00:00, 15.58it/s]
# Rejection Sampling:  99%|██████████████████████████████████████████████████████████████████████████████████████████████████████▊ | 1444/1461 [01:32<00:01, 15.58it/s]
# Rejection Sampling:  99%|███████████████████████████████████████████████████████████████████████████████████████████████████████▏| 1450/1462 [01:32<00:00, 15.56it/s]
# Rejection Sampling:  99%|██████████████████████████████████████████████████████████████████████████████████████████████████████▋ | 1443/1461 [01:32<00:01, 15.90it/s]
# Rejection Sampling:  99%|██████████████████████████████████████████████████████████████████████████████████████████████████████▊ | 1446/1462 [01:32<00:01, 15.57it/s]
# Rejection Sampling:  98%|██████████████████████████████████████████████████████████████████████████████████████████████████████▎ | 1438/1462 [01:32<00:01, 15.44it/s]
# Rejection Sampling:  99%|███████████████████████████████████████████████████████████████████████████████████████████████████████▍| 1454/1462 [01:32<00:00, 15.80it/s]
# Rejection Sampling:  99%|███████████████████████████████████████████████████████████████████████████████████████████████████████▏| 1450/1461 [01:32<00:00, 15.84it/s]
# Rejection Sampling:  99%|███████████████████████████████████████████████████████████████████████████████████████████████████████▎| 1452/1462 [01:32<00:00, 15.81it/s]
# Rejection Sampling:  99%|██████████████████████████████████████████████████████████████████████████████████████████████████████▋ | 1444/1462 [01:32<00:01, 15.76it/s]
# Rejection Sampling:  99%|██████████████████████████████████████████████████████████████████████████████████████████████████████▉ | 1446/1461 [01:32<00:00, 15.77it/s]
# Rejection Sampling:  99%|██████████████████████████████████████████████████████████████████████████████████████████████████████▊ | 1445/1461 [01:32<00:00, 16.01it/s]
# Rejection Sampling:  99%|███████████████████████████████████████████████████████████████████████████████████████████████████████ | 1448/1462 [01:32<00:00, 15.00it/s]
# Rejection Sampling:  98%|██████████████████████████████████████████████████████████████████████████████████████████████████████▍ | 1440/1462 [01:32<00:01, 14.21it/s]
# Rejection Sampling: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████▌| 1456/1462 [01:32<00:00, 15.83it/s]
# Rejection Sampling:  99%|███████████████████████████████████████████████████████████████████████████████████████████████████████▎| 1452/1461 [01:32<00:00, 15.90it/s]
# Rejection Sampling:  99%|██████████████████████████████████████████████████████████████████████████████████████████████████████▊ | 1446/1462 [01:32<00:01, 15.90it/s]
# Rejection Sampling:  99%|███████████████████████████████████████████████████████████████████████████████████████████████████████ | 1448/1461 [01:32<00:00, 15.89it/s]
# Rejection Sampling:  99%|███████████████████████████████████████████████████████████████████████████████████████████████████████ | 1447/1461 [01:32<00:00, 16.06it/s]
# Rejection Sampling:  99%|███████████████████████████████████████████████████████████████████████████████████████████████████████▍| 1454/1462 [01:32<00:00, 15.87it/s]
# Rejection Sampling:  99%|███████████████████████████████████████████████████████████████████████████████████████████████████████▏| 1450/1462 [01:32<00:00, 15.17it/s]
# Rejection Sampling:  99%|██████████████████████████████████████████████████████████████████████████████████████████████████████▌ | 1442/1462 [01:32<00:01, 14.48it/s]
# Rejection Sampling: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████▋| 1458/1462 [01:32<00:00, 15.95it/s]
# Rejection Sampling: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████▌| 1454/1461 [01:32<00:00, 15.92it/s]
# Rejection Sampling: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████▌| 1456/1462 [01:32<00:00, 15.93it/s]
# Rejection Sampling:  99%|███████████████████████████████████████████████████████████████████████████████████████████████████████▏| 1450/1461 [01:32<00:00, 15.94it/s]
# Rejection Sampling:  99%|███████████████████████████████████████████████████████████████████████████████████████████████████████▏| 1449/1461 [01:32<00:00, 16.06it/s]
# Rejection Sampling:  99%|███████████████████████████████████████████████████████████████████████████████████████████████████████ | 1448/1462 [01:32<00:00, 15.86it/s]
# Rejection Sampling:  99%|███████████████████████████████████████████████████████████████████████████████████████████████████████▎| 1452/1462 [01:32<00:00, 15.28it/s]
# Rejection Sampling: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████▊| 1460/1462 [01:33<00:00, 15.95it/s]
# Rejection Sampling:  99%|██████████████████████████████████████████████████████████████████████████████████████████████████████▋ | 1444/1462 [01:32<00:01, 14.65it/s]
# Rejection Sampling: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████▋| 1456/1461 [01:33<00:00, 15.91it/s]
# Rejection Sampling: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████▋| 1458/1462 [01:33<00:00, 15.88it/s]
# Rejection Sampling:  99%|███████████████████████████████████████████████████████████████████████████████████████████████████████▎| 1451/1461 [01:32<00:00, 16.00it/s]
# Rejection Sampling:  99%|███████████████████████████████████████████████████████████████████████████████████████████████████████▏| 1450/1462 [01:33<00:00, 15.92it/s]
# Rejection Sampling:  99%|███████████████████████████████████████████████████████████████████████████████████████████████████████▎| 1452/1461 [01:33<00:00, 15.88it/s]
# Rejection Sampling:  99%|███████████████████████████████████████████████████████████████████████████████████████████████████████▍| 1454/1462 [01:33<00:00, 15.34it/s]
# Rejection Sampling: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████| 1462/1462 [01:33<00:00, 15.86it/s]
# Rejection Sampling:  99%|██████████████████████████████████████████████████████████████████████████████████████████████████████▊ | 1446/1462 [01:33<00:01, 14.95it/s]
# Rejection Sampling: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████▊| 1458/1461 [01:33<00:00, 16.04it/s]
# Rejection Sampling:  99%|███████████████████████████████████████████████████████████████████████████████████████████████████████▍| 1453/1461 [01:33<00:00, 16.10it/s]
# Rejection Sampling:  99%|███████████████████████████████████████████████████████████████████████████████████████████████████████▎| 1452/1462 [01:33<00:00, 16.02it/s]
# Rejection Sampling: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████▊| 1460/1462 [01:33<00:00, 16.03it/s]
# Rejection Sampling: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████▌| 1454/1461 [01:33<00:00, 16.01it/s]
# Rejection Sampling: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████▌| 1456/1462 [01:33<00:00, 15.79it/s]
# Rejection Sampling:  99%|███████████████████████████████████████████████████████████████████████████████████████████████████████ | 1448/1462 [01:33<00:00, 15.62it/s]
# Rejection Sampling: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████| 1462/1462 [01:33<00:00, 16.52it/s]
# Rejection Sampling:  99%|███████████████████████████████████████████████████████████████████████████████████████████████████████▍| 1454/1462 [01:33<00:00, 16.49it/s]
# Rejection Sampling: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████▉| 1460/1461 [01:33<00:00, 16.45it/s]
# Rejection Sampling: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████▌| 1455/1461 [01:33<00:00, 16.55it/s]
# Rejection Sampling: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████▋| 1456/1461 [01:33<00:00, 16.52it/s]
# Rejection Sampling: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████▋| 1458/1462 [01:33<00:00, 16.52it/s]
# Rejection Sampling:  99%|███████████████████████████████████████████████████████████████████████████████████████████████████████▏| 1450/1462 [01:33<00:00, 16.25it/s]
# Rejection Sampling: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████▌| 1456/1462 [01:33<00:00, 17.36it/s]
# Rejection Sampling: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████▋| 1457/1461 [01:33<00:00, 17.38it/s]
# Rejection Sampling: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████▊| 1458/1461 [01:33<00:00, 17.35it/s]
# Rejection Sampling: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████▉| 1461/1462 [01:33<00:00, 18.87it/s]
# Rejection Sampling:  99%|███████████████████████████████████████████████████████████████████████████████████████████████████████▎| 1453/1462 [01:33<00:00, 18.08it/s]
# Rejection Sampling: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████▉| 1460/1461 [01:33<00:00, 19.15it/s]
# Rejection Sampling: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████| 1461/1461 [01:33<00:00, 19.12it/s]
# Rejection Sampling: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████▊| 1459/1462 [01:33<00:00, 19.06it/s]
# Rejection Sampling: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████▌| 1456/1462 [01:33<00:00, 20.44it/s]
# Rejection Sampling: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████▊| 1460/1462 [01:33<00:00, 25.05it/s]
# integrate_rejection: Time= 93.9s/11693 soundings,  8.0ms/sounding, 124.5it/s. T_av=20.9, EV_av=-49.9
# Computing posterior statistics for 11693 of 11693 data points
# Computing number of unique realizations (N_UNIQUE)
# N_UNIQUE:   0%|                                                                                                                            | 0/11693 [00:00<?, ?it/s]
# Updating /N_UNIQUE in POST.h5
# M1-continuous:   0%|                                                                                                                       | 0/11693 [00:00<?, ?it/s]
# M1-continuous:   6%|██████▍                                                                                                     | 700/11693 [00:01<00:15, 699.88it/s]
# M1-continuous:  12%|████████████▊                                                                                              | 1400/11693 [00:02<00:14, 691.65it/s]
# M1-continuous:  18%|███████████████████▎                                                                                       | 2112/11693 [00:03<00:13, 700.50it/s]
# M1-continuous:  24%|█████████████████████████▊                                                                                 | 2823/11693 [00:04<00:12, 704.56it/s]
# M1-continuous:  30%|████████████████████████████████▍                                                                          | 3543/11693 [00:05<00:11, 709.76it/s]
# M1-continuous:  37%|███████████████████████████████████████                                                                    | 4268/11693 [00:06<00:10, 714.64it/s]
# M1-continuous:  43%|█████████████████████████████████████████████▌                                                             | 4984/11693 [00:07<00:09, 714.81it/s]
# M1-continuous:  49%|████████████████████████████████████████████████████▍                                                      | 5736/11693 [00:08<00:08, 726.49it/s]
# M1-continuous:  55%|███████████████████████████████████████████████████████████▎                                               | 6481/11693 [00:09<00:07, 732.23it/s]
# M1-continuous:  62%|██████████████████████████████████████████████████████████████████                                         | 7214/11693 [00:10<00:06, 724.64it/s]
# M1-continuous:  68%|████████████████████████████████████████████████████████████████████████▋                                  | 7941/11693 [00:11<00:05, 725.34it/s]
# M1-continuous:  74%|███████████████████████████████████████████████████████████████████████████████▎                           | 8667/11693 [00:12<00:04, 718.68it/s]
# M1-continuous:  80%|█████████████████████████████████████████████████████████████████████████████████████▉                     | 9391/11693 [00:13<00:03, 720.26it/s]
# M1-continuous:  86%|███████████████████████████████████████████████████████████████████████████████████████████▋              | 10112/11693 [00:14<00:02, 718.71it/s]
# M1-continuous:  93%|██████████████████████████████████████████████████████████████████████████████████████████████████▏       | 10831/11693 [00:15<00:01, 717.49it/s]
# M1-continuous:  99%|████████████████████████████████████████████████████████████████████████████████████████████████████████▋ | 11549/11693 [00:16<00:00, 714.42it/s]
# Creating /M1/Mean in POST.h5
# Creating /M1/Median in POST.h5
# Creating /M1/Std in POST.h5
# Creating /M1/LogStd in POST.h5
# Creating /M1/LogMean in POST.h5
# Creating /M1/HarmonicMean in POST.h5
# Creating /M2/Mode in POST.h5
# Creating /M2/Entropy in POST.h5
# Creating /M2/P
# M2-discrete:   0%|                                                                                                                         | 0/11693 [00:00<?, ?it/s]
# M2-discrete:  17%|██████████████████▍                                                                                         | 1999/11693 [00:01<00:04, 1998.45it/s]
# M2-discrete:  34%|█████████████████████████████████████                                                                       | 4012/11693 [00:02<00:03, 2006.84it/s]
# M2-discrete:  52%|███████████████████████████████████████████████████████▋                                                    | 6034/11693 [00:03<00:02, 2013.55it/s]
# M2-discrete:  69%|██████████████████████████████████████████████████████████████████████████▎                                 | 8048/11693 [00:04<00:01, 2012.18it/s]
# M2-discrete:  86%|████████████████████████████████████████████████████████████████████████████████████████████               | 10063/11693 [00:05<00:00, 2013.15it/s]

# %%
# This is typically done after the inversion
# ig.integrate_posterior_stats(f_post_h5)

# %% [markdown]
# ## 3. Plot some statistics from $\sigma(\mathbf{m})$
#
# ### Prior and posterior data
# First, compare prior (beige) to posterior (black) data, as well as observed data (red), for two specific data IDs.

# %%
ig.plot_data_prior_post(f_post_h5, i_plot=100,hardcopy=hardcopy)
ig.plot_data_prior_post(f_post_h5, i_plot=0,hardcopy=hardcopy)

# %% [markdown]
# ### Evidence and Temperature

# %%
# Plot the Temperature used for inversion
ig.plot_T_EV(f_post_h5, pl='T',hardcopy=hardcopy)
# Plot the evidence (prior likelihood) estimated as part of inversion
ig.plot_T_EV(f_post_h5, pl='EV',hardcopy=hardcopy)
# Out:
# Figure saved to POST_1_11693_T.png
# Figure saved to POST_1_11693_EV.png

# %% [markdown]
# ### Profile
#
# Plot a profile of posterior statistics of model parameters 1 (resistivity)

# %%
ig.plot_profile(f_post_h5, i1=1, i2=2000, im=1, hardcopy=hardcopy)
# Out:
# Getting cmap from attribute

# %% [markdown]
# ### Plot 2d Features
#
# First plot the median resistivity in layers 5, 30, and 50

# %%
# Plot a 2D feature: Resistivity in layer 10
try:
    ig.plot_feature_2d(f_post_h5,im=1,iz=5, key='Median', uselog=1, cmap='jet', s=10,hardcopy=hardcopy)
    plt.show()
except:
    pass

try:
    ig.plot_feature_2d(f_post_h5,im=1,iz=30, key='Median', uselog=1, cmap='jet', s=10,hardcopy=hardcopy)
    plt.show()
except:
    pass

try:
    ig.plot_feature_2d(f_post_h5,im=1,iz=50, key='Median', uselog=1, cmap='jet', s=10,hardcopy=hardcopy)
    plt.show()
except:
    pass
# Out:
# /M1/Median[5,:] Resistivity
# /M1/Median[30,:] Resistivity
# /M1/Median[50,:] Resistivity

# %% [markdown]
# ## Export to CSV format

# %%
f_csv, f_point_csv = ig.post_to_csv(f_post_h5)
# Out:
# Writing to POST_M1.csv
# ----------------------------------------------------
# Creating point data set: Median
# Creating point data set: Mean
# Creating point data set: Std
# - saving to : POST_M1_point.csv

# %%
# Read the CSV file
#f_point_csv = 'POST_DAUGAARD_AVG_PRIOR_CHI2_NF_3_log-uniform_N100000_TX07_20231016_2x4_RC20-33_Nh280_Nf12_Nu100000_aT1_M1_point.csv'
import pandas as pd
df = pd.read_csv(f_point_csv)
df.head()
# Out:
#           X          Y      Z   LINE     Median       Mean        Std
# 0  543822.9  6176069.6  58.82  140.0  18.247494  19.782888   9.729237
# 1  543822.9  6176069.6  57.82  140.0  17.544641  18.815121   6.243499
# 2  543822.9  6176069.6  56.82  140.0  16.176577  17.096075   5.960819
# 3  543822.9  6176069.6  55.82  140.0  16.741793  18.979637  10.031297
# 4  543822.9  6176069.6  54.82  140.0  18.782154  22.265501  12.155263

# %%
# Use Pyvista to plot X,Y,Z,Median
plPyVista = False
if plPyVista:
    import pyvista as pv
    import numpy as np
    from pyvista import examples
    #pv.set_jupyter_backend('client')
    pv.set_plot_theme("document")
    p = pv.Plotter(notebook=True)
    p = pv.Plotter()
    filtered_df = df[(df['Median'] < 50) | (df['Median'] > 200)]
    #filtered_df = df[(df['LINE'] > 1000) & (df['LINE'] < 1400) ]
    points = filtered_df[['X', 'Y', 'Z']].values[:]
    median = np.log10(filtered_df['Mean'].values[:])
    opacity = np.where(filtered_df['Median'].values[:] < 100, 0.5, 1.0)
    #p.add_points(points, render_points_as_spheres=True, point_size=3, scalars=median, cmap='jet', opacity=opacity)
    p.add_points(points, render_points_as_spheres=True, point_size=6, scalars=median, cmap='hot')
    p.show_grid()
    p.show()
